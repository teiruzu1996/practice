# %%
a = 3

# %%
a
# Out:
# 3

# %%
B =10

# %%
B
# Out:
# 10

# %%
a+B
# Out:
# 13

# %%
price = 100

# %%
tax = 0.08

# %%
price * tax
# Out:
# 8.0

# %%
c = 10+3
c
# Out:
# 13

# %%
name = '那須'

# %%
name
# Out:
# '那須'

# %%
print(name)
# Out:
# 那須
